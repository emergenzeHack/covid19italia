# %%
from github import Github
import datetime
import csv
import sys
from lxml import html
import json
import yaml
from configparser import ConfigParser 
import os
import pandas as pd

FILTER_LABELS=("Accettato",)

try:
    config=ConfigParser()
    config.read('../../.github.cfg')

    TOKEN=config.get('GitHub','TOKEN')
    USER=config.get('GitHub','USER')
    REPO_NAME=config.get('GitHub','REPO_NAME')
    ORG=config.get('GitHub','ORG')
except Exception as m:
    print(m)
    TOKEN=os.environ.get('GITHUB_PASSWORD')
    USER=os.environ.get('GITHUB_USERNAME')
    REPO_NAME='terremotocentro_segnalazioni'
    ORG='emergenzeHack'

if not TOKEN:
    print ("Need a TOKEN")
    sys.exit(1)

if not USER:
    print ("Need a USER")
    sys.exit(1)

if not REPO_NAME:
    print ("Need a REPO_NAME")
    sys.exit(1)

if not ORG:
    print ("Need a ORG")
    sys.exit(1)

CSVFILE=sys.argv[1]

try:
    JSONFILE=sys.argv[2]
    jwr=file(JSONFILE,"w+")
except:
    jwr=None

try:
    GEOJSONFILE=sys.argv[3]
    gjwr=file(GEOJSONFILE,"w+")
except:
    gjwr=None


g = Github(USER, TOKEN)
org=g.get_organization(ORG)
r = org.get_repo(REPO_NAME)

# %%
donazioni=pd.read_csv("Mappatura_resilienzacomunitaria - donazioni.csv")

# %%
donazioni.columns
# Out:
# Index(['comune', 'provincia', 'regione', 'chi', 'descrizione', 'destinatari',
#        'contatti', 'fonte', 'tag'],
#       dtype='object')

# %%
for i,row in donazioni.fillna("").iterrows():
    y='<pre><yamldata>'+yaml.dump(dict(row))+'</yamldata></pre>'
    #print (dict(row))
    try:
        r.create_issue(title=row['descrizione'], body=y,labels=[row['tag']])
    except Exception as m:
        print(m)
        pass
# Out:
# {'comune': 'Lecce', 'provincia': 'Lecce', 'regione': 'Puglia', 'chi': 'Luigi E. Conte & Co.', 'descrizione': "Raccolta fondi per aumentare i posti di terapia intensiva dell'ospedale Vito Fazzi e permettere all'ASL di Lecce l'acquisto di materiale destinati a contrastare la diffusione del virus in ambito sanitario.", 'destinatari': 'Ospedale Vito Fazzi Lecce', 'contatti': '', 'fonte': 'https://www.gofundme.com/f/2dqhr-coronavirus-rafforziamo-la-terapia-intensiva?utm_medium=copy_link&utm_source=customer&utm_campaign=p_lico+share-sheet+exp4vb', 'tag': 'Raccolta fondi'}
# {'comune': 'Lodi', 'provincia': 'Lodi', 'regione': 'Lombardia', 'chi': 'Caritas Lodi', 'descrizione': 'gf.me/u/xqbgu5', 'destinatari': 'Caritas Lodi', 'contatti': '', 'fonte': 'https://bit.ly/39Dmuzl', 'tag': 'Raccolta fondi'}
# {'comune': 'Italia', 'provincia': 'Italia', 'regione': 'Italia', 'chi': 'Elisa Stagnati e Alessandra Sellitto', 'descrizione': 'Raccolta fondi Protezione Civile', 'destinatari': '', 'contatti': '', 'fonte': 'https://iorestoacasa.com/index.html?fbclid=IwAR3tBE9QR7Tj_rh624rC2xb0OEdyJjqmvwRKgHdPpqjtHAT-wj51s3UhcK8', 'tag': 'Raccolta fondi'}
# {'comune': 'Bergamo', 'provincia': 'Bergamo', 'regione': 'Lombardia', 'chi': 'Ass.ne Papa Giovanni XXIII', 'descrizione': '', 'destinatari': 'Ospedale Bergamo', 'contatti': '', 'fonte': 'https://m.facebook.com/story.php?story_fbid=2233056337001294&id=1497288917244710', 'tag': 'Raccolta fondi'}
# 422 {'message': 'Validation Failed', 'errors': [{'resource': 'Issue', 'code': 'missing_field', 'field': 'title'}], 'documentation_url': 'https://developer.github.com/v3/issues/#create-an-issue'}
# {'comune': 'Cremona', 'provincia': 'Milano', 'regione': 'Lombardia', 'chi': '', 'descrizione': 'Raccolta fondi per rafforzare la terapia intensiva', 'destinatari': 'Ospedale di Cremona', 'contatti': '', 'fonte': 'https://www.gofundme.com/f/raccolta-fondi-per-l039-ospedale-di-cremona', 'tag': 'Raccolta fondi'}
# {'comune': 'Milano', 'provincia': 'Milano', 'regione': 'Lombardia', 'chi': 'The Ferragnez', 'descrizione': 'Raccolta fondi per rafforzare la terapia intensiva', 'destinatari': 'San Raffaele di MIlano', 'contatti': '', 'fonte': 'https://www.gofundme.com/f/coronavirus-terapia-intensiva?fbclid=IwAR1LscOtahbuNMnvht_Y4DOIAVk0epdV1HnDdeF1q4g8ifYzd4yJrB2DLPc', 'tag': 'Raccolta fondi'}
# {'comune': 'Pavia', 'provincia': 'Pavia', 'regione': 'Lombardia', 'chi': 'Croce Rossa Italiana- Pavia', 'descrizione': 'Raccolta fondi Croce Rossa Italiana', 'destinatari': 'Croce Rossa', 'contatti': '', 'fonte': 'https://www.facebook.com/donate/492487048085274/?fundraiser_source=external_url', 'tag': 'Raccolta fondi'}
# {'comune': 'Italia', 'provincia': 'Italia', 'regione': 'Italia', 'chi': 'Save The Planet Onlus', 'descrizione': '#iorestoacasa: acquisto di altri presidi ospedalieri utili a supportare il lavoro di tutte le strutture sanitarie in Italia. ', 'destinatari': 'Protezione Civile', 'contatti': '', 'fonte': 'https://iorestoacasa.com/index.html?fbclid=IwAR3Ig4Q3J_y-FM8YggN5RwhkxFfpwEqwDf8kkUOP8_6gJiv23kWF-fYv3GE', 'tag': 'Raccolta fondi'}
# {'comune': 'Bologna', 'provincia': 'Bologna', 'regione': 'Emilia Romagna', 'chi': 'Ospedale Sant´Orsola', 'descrizione': 'Donazione Osp. SantÓrsola-Malpighi', 'destinatari': 'Ospedale Sant´Orsola', 'contatti': '', 'fonte': 'https://www.aosp.bo.it/content/fai-una-donazione?fbclid=IwAR2pTgWfhpFiOxEOTJEbbXWSisYdNrgoK9nOAHBImYSPmR1qG3iADLltu3s', 'tag': 'Raccolta fondi'}
# {'comune': 'Cosenza', 'provincia': 'Cosenza', 'regione': 'Calabria', 'chi': 'Alfredo Taranto', 'descrizione': 'Raccolta per Azienda Ospedaliera di Cosenza per l’acquisto di materiale medico e/o sanitario', 'destinatari': 'Annunziata di Cosenza', 'contatti': '', 'fonte': 'https://www.gofundme.com/f/calabria-anticovid', 'tag': 'Raccolta fondi'}
# {'comune': 'Lodi', 'provincia': 'Lodi', 'regione': 'Lombardia', 'chi': 'Associazione Volontaria Croce Casalese e Paesi Limitrofi', 'descrizione': "Raccolta fondi per acquisto di materiale di protezione individuale (mascherine FFP2/3, disinfettanti, tute protettive, guanti e occhiali) e altri presidi di tipo essenziale per l'implementazione dei protocolli d'emergenza.", 'destinatari': 'residenti prov. Lodi', 'contatti': '', 'fonte': 'https://www.gofundme.com/f/vqmkx9-aiutaci-ad-aiutare?fbclid=IwAR2_nOU3wD4aWialN-fGVF8MfSpZG-iSFUYiQqMjgZU3NogavzdOP0nhzBY', 'tag': 'Raccolta fondi'}
# {'comune': 'Brescia', 'provincia': 'Brescia', 'regione': 'Lombardia', 'chi': 'Fondazione Comunita Bresciana Onlus', 'descrizione': 'Raccolta fondi per Ospedali bresciani', 'destinatari': 'ospedali di Brescia', 'contatti': '', 'fonte': 'https://www.giornaledibrescia.it/brescia-e-hinterland/aiutiamobrescia-la-raccolta-fondi-per-gli-ospedali-bresciani-1.3465790?fbclid=IwAR0nAj44EoQXlyk9Cf22_L0wBojOPTtlOgizEHPZsVBp1JPNrAbMHuoGVRw', 'tag': 'Raccolta fondi'}
# {'comune': 'Monza', 'provincia': 'Monza', 'regione': 'Lombardia', 'chi': 'Croce Rossa Monza', 'descrizione': 'acquisto di materiale di protezione per i volontari', 'destinatari': 'tutt', 'contatti': '', 'fonte': 'https://www.gofundme.com/f/yqppre-cri-monza-coronavirus-2019', 'tag': 'Raccolta fondi'}
# {'comune': '', 'provincia': '', 'regione': 'Puglia', 'chi': 'Barbara Palazzi', 'descrizione': 'potenziare i quantitativi di ventilatori polmonari e monitor multi parametrici.', 'destinatari': 'ospedali Puglia', 'contatti': '', 'fonte': 'https://www.gofundme.com/f/tztxv-rafforziamo-la-terapia-intensiva-a-bari?utm_source=facebook&utm_medium=social&utm_campaign=m_pd+share-sheet&fbclid=IwAR0HdYdw3_wA_a79mIxkgPdQShyluXmdyMFzV2KKkyhJPA69M97tsiw9oY4', 'tag': 'Raccolta fondi'}
# {'comune': '', 'provincia': '', 'regione': 'Lombardia', 'chi': 'Fondazione Cariplo', 'descrizione': '', 'destinatari': '', 'contatti': '', 'fonte': '', 'tag': ''}
# 422 {'message': 'Validation Failed', 'errors': [{'resource': 'Label', 'field': 'name', 'code': 'missing_field'}], 'documentation_url': 'https://developer.github.com/v3/issues/#create-an-issue'}
# {'comune': 'Jesi', 'provincia': 'Ancona', 'regione': 'Marche', 'chi': 'ImpAct Associazione Culturale', 'descrizione': 'potenziamento attrezzature', 'destinatari': 'Ospedale Carlo Urbani', 'contatti': '', 'fonte': 'https://it-it.facebook.com/associazioneimpact/', 'tag': 'Raccolta fondi'}
# {'comune': 'Ancona', 'provincia': 'Ancona', 'regione': 'Marche', 'chi': 'privata cittadina in collaborazione con azienda ospedaliera', 'descrizione': 'potenziamento terapia intensiva', 'destinatari': 'Azienda Ospedali Riuniti di Torrette', 'contatti': '', 'fonte': 'https://www.gofundme.com/f/donazione-per-ospedale-torrette?utm_source=customer&utm_medium=copy_link&utm_campaign=m_pd+share-sheet', 'tag': 'Raccolta fondi'}
# {'comune': 'Bergamo', 'provincia': 'Bergamo', 'regione': 'Lombardia', 'chi': "tifosi dell'Atalanta", 'descrizione': "donazione per l'ospedale di Bergamo", 'destinatari': '', 'contatti': '', 'fonte': 'https://www.inews24.it/2020/03/10/atalanta-solidarieta-tifosi-coronavirus-ospedale-bergamo/', 'tag': 'Raccolta fondi'}
# {'comune': 'Roma', 'provincia': 'Roma', 'regione': 'Lazio', 'chi': "Comunità di Sant'Egidio", 'descrizione': 'generi utili, come alimentari, gel igienizzanti e fazzoletti di carta per senzatetto e anziani', 'destinatari': "Comunità di Sant'Egidio", 'contatti': '', 'fonte': 'https://www.facebook.com/donate/503579490301582/10221812290241438/', 'tag': 'Raccolta fondi'}
# {'comune': 'Chivasso', 'provincia': 'Torino', 'regione': 'Piemonte', 'chi': 'Francesco Pecco Bagnaia', 'descrizione': 'Raccolta Fondi', 'destinatari': 'Città della Salute di Torino ', 'contatti': '', 'fonte': 'https://www.gofundme.com/f/exfz34-insieme-contro-il-virus?utm_source=customer&utm_medium=copy_link-tip&utm_campaign=p_cp+share-sheet', 'tag': 'Raccolta fondi'}
# {'comune': 'Catanzaro', 'provincia': 'Catanzaro', 'regione': 'Calabria', 'chi': 'Club Service Catanzaro', 'descrizione': 'Raccolta Fondi', 'destinatari': 'Azienda Ospedaliera “Pugliese-Ciaccio”', 'contatti': '', 'fonte': 'https://www.gofundme.com/f/emergenza-covid19-aiutiamo-il-puglieseciaccio?utm_source=customer&utm_medium=copy_link-tip&utm_campaign=p_cp+share-sheet&fbclid=IwAR1expolR3-WdZT3pG7XCrJVH401W8bcGI8unHh9b_X1Zv63PmufHsRac8A', 'tag': 'Raccolta fondi'}
# {'comune': 'Lamezia Terme', 'provincia': 'Cosenza', 'regione': 'Calabria', 'chi': 'Vincenzo Bernardi', 'descrizione': 'Raccolta Fondi', 'destinatari': 'Ospedale di Lamezia Terme', 'contatti': '', 'fonte': 'https://www.gofundme.com/f/raccolta-fondi-covid19-ospedale-di-lamezia-terme?fbclid=IwAR2gUvAXo5xe0FnNGEPc8_FOx3xiDHC18QPA0RCiYt53TZyiZ8hqYHT4tMk', 'tag': 'Raccolta fondi'}
# {'comune': 'Tutta Italia', 'provincia': '', 'regione': '', 'chi': 'Fondazione Arca', 'descrizione': 'Raccolta fondi', 'destinatari': 'Operatori servizi persone senza dimora ', 'contatti': '', 'fonte': 'https://www.facebook.com/donate/543942392915387/', 'tag': 'Raccolta fondi'}
# {'comune': '', 'provincia': '', 'regione': 'Abruzzo', 'chi': 'pagine social abruzzesi', 'descrizione': 'campagna di raccolta fondi che mira allo scopo (simbolico) di 100.000 € che saranno distribuiti in parti uguali alle ASL provinciali per potenziare la terapia intensiva', 'destinatari': 'ASL Abruzzo', 'contatti': '', 'fonte': 'https://www.gofundme.com/f/abruzzo-rafforziamo-la-terapia-intensiva?utm_source=customer&utm_medium=copy_link-tip&utm_campaign=p_cp+share-sheet', 'tag': 'Raccolta fondi'}

# %%
ii=pd.read_csv("Mappatura_resilienzacomunitaria - iniziative istituzionali.csv")

# %%
ii.head()
# Out:
#     comune provincia    regione                          chi  \
# 0   Milano    Milano  Lombardia             Comune di Milano
# 1   Italia    Italia     Italia  Agid - Solidarietà digitale
# 2  Bergamo   Bergamo  Lombardia           Fondazione Bergamo
# 3   Ancona    Ancona     Marche                Comune Ancona
# 4  Palermo        Pa     Italia    Teatro Massimo di Palermo
#
#                                          descrizione        destinatari  \
# 0  Raccolta disponibilità per servizi di sostegno...                NaN
# 1  Sito che raccoglie tutti i servizi digitali gr...                NaN
# 2  sostegno agli anziani in condizione di solitud...            over 65
# 3  potenziamento Pronto Intervento Sociale: spesa...  anziani, disabili
# 4  Programmazione no stop streaming di opere, con...              Tutti
#
#                                             contatti  \
# 0                       milanoaiuta@comune.milano.it
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  http://www.teatromassimo.it/archivio/notizie/n...
#
#                                                fonte  \
# 0  https://www.comune.milano.it/-/politiche-socia...
# 1  https://solidarietadigitale.agid.gov.it/?fbcli...
# 2  http://www.fondazionebergamo.it/news/sosteniam...
# 3                                                NaN
# 4                                                NaN
#
#                                        tag
# 0  Servizi e iniziative solidali pubbliche
# 1  Servizi e iniziative solidali pubbliche
# 2                           Raccolta fondi
# 3  Servizi e iniziative solidali pubbliche
# 4  Servizi e iniziative solidali pubbliche

# %%
for i,row in ii.fillna("").iterrows():
    y='<pre><yamldata>'+yaml.dump(dict(row))+'</yamldata></pre>'
    #print (dict(row))
    try:
        r.create_issue(title=row['descrizione'], body=y,labels=[row['tag']])
    except Exception as m:
        print(m)
        pass
# Out:
# 422 {'message': 'Validation Failed', 'errors': [{'resource': 'Label', 'field': 'name', 'code': 'missing_field'}], 'documentation_url': 'https://developer.github.com/v3/issues/#create-an-issue'}

# %%
insolidali=pd.read_csv('Mappatura_resilienzacomunitaria - Iniziative solidali.csv')

# %%
insolidali.head()
# Out:
#     comune provincia         regione  \
# 0   Torino    Torino        Piemonte
# 1  Fidenza     Parma  Emilia-Romagna
# 2     Roma      Roma           Lazio
# 3      NaN       NaN             NaN
# 4   Milano    Milano      Lombardia
#
#                                              chi  \
# 0                                            NaN
# 1                      Gruppo Scout Agesci 1 e 2
# 2                        Circolo Arci Sparwasser
# 3                               Smk Videofactory
# 4  Comitato Abitanti San Siro, associazione Naga
#
#                                          descrizione destinatari contatti  \
# 0                                                NaN         NaN      NaN
# 1                                                NaN         NaN      NaN
# 2                                                NaN         NaN      NaN
# 3                              streaming di comunità         NaN      NaN
# 4  Traduzione in 7 lingue decalogo Ministero dell...         NaN      NaN
#
#                                                fonte  \
# 0  https://torino.corriere.it/cronaca/20_marzo_07...
# 1  https://parma.repubblica.it/cronaca/2020/03/07...
# 2  https://www.facebook.com/ArciSparwasser/photos...
# 3      https://www.openddb.it/streaming-di-comunita/
# 4  http://www.milanotoday.it/attualita/coronaviru...
#
#                                      tag
# 0                 Consegne e commissioni
# 1                 Consegne e commissioni
# 2  Servizi e iniziative solidali private
# 3                     Sostegno al lavoro
# 4                     Sostegno al lavoro

# %%
for i,row in insolidali.fillna("").iterrows():
    y='<pre><yamldata>'+yaml.dump(dict(row))+'</yamldata></pre>'
    #print (dict(row))
    try:
        r.create_issue(title=row['descrizione'], body=y,labels=[row['tag']])
    except Exception as m:
        print(m)
        pass
# Out:
# 422 {'message': 'Validation Failed', 'errors': [{'resource': 'Issue', 'code': 'missing_field', 'field': 'title'}], 'documentation_url': 'https://developer.github.com/v3/issues/#create-an-issue'}
# 422 {'message': 'Validation Failed', 'errors': [{'resource': 'Issue', 'code': 'missing_field', 'field': 'title'}], 'documentation_url': 'https://developer.github.com/v3/issues/#create-an-issue'}
# 422 {'message': 'Validation Failed', 'errors': [{'resource': 'Issue', 'code': 'missing_field', 'field': 'title'}], 'documentation_url': 'https://developer.github.com/v3/issues/#create-an-issue'}
# 422 {'message': 'Validation Failed', 'errors': [{'resource': 'Issue', 'code': 'missing_field', 'field': 'title'}], 'documentation_url': 'https://developer.github.com/v3/issues/#create-an-issue'}
# 422 {'message': 'Validation Failed', 'errors': [{'resource': 'Issue', 'code': 'missing_field', 'field': 'title'}], 'documentation_url': 'https://developer.github.com/v3/issues/#create-an-issue'}
# 422 {'message': 'Validation Failed', 'errors': [{'resource': 'Issue', 'code': 'missing_field', 'field': 'title'}], 'documentation_url': 'https://developer.github.com/v3/issues/#create-an-issue'}
# 422 {'message': 'Validation Failed', 'errors': [{'resource': 'Issue', 'code': 'missing_field', 'field': 'title'}], 'documentation_url': 'https://developer.github.com/v3/issues/#create-an-issue'}
# 422 {'message': 'Validation Failed', 'errors': [{'resource': 'Issue', 'code': 'missing_field', 'field': 'title'}], 'documentation_url': 'https://developer.github.com/v3/issues/#create-an-issue'}
# 422 {'message': 'Validation Failed', 'errors': [{'resource': 'Issue', 'code': 'missing_field', 'field': 'title'}], 'documentation_url': 'https://developer.github.com/v3/issues/#create-an-issue'}
# 422 {'message': 'Validation Failed', 'errors': [{'resource': 'Issue', 'code': 'missing_field', 'field': 'title'}], 'documentation_url': 'https://developer.github.com/v3/issues/#create-an-issue'}
# 422 {'message': 'Validation Failed', 'errors': [{'resource': 'Issue', 'code': 'missing_field', 'field': 'title'}], 'documentation_url': 'https://developer.github.com/v3/issues/#create-an-issue'}
# 422 {'message': 'Validation Failed', 'errors': [{'resource': 'Issue', 'code': 'missing_field', 'field': 'title'}], 'documentation_url': 'https://developer.github.com/v3/issues/#create-an-issue'}
# 422 {'message': 'Validation Failed', 'errors': [{'resource': 'Issue', 'code': 'missing_field', 'field': 'title'}], 'documentation_url': 'https://developer.github.com/v3/issues/#create-an-issue'}
# 422 {'message': 'Validation Failed', 'errors': [{'resource': 'Issue', 'code': 'missing_field', 'field': 'title'}], 'documentation_url': 'https://developer.github.com/v3/issues/#create-an-issue'}
# 422 {'message': 'Validation Failed', 'errors': [{'resource': 'Issue', 'code': 'missing_field', 'field': 'title'}], 'documentation_url': 'https://developer.github.com/v3/issues/#create-an-issue'}
# 422 {'message': 'Validation Failed', 'errors': [{'resource': 'Issue', 'code': 'missing_field', 'field': 'title'}], 'documentation_url': 'https://developer.github.com/v3/issues/#create-an-issue'}
# 422 {'message': 'Validation Failed', 'errors': [{'resource': 'Issue', 'code': 'missing_field', 'field': 'title'}], 'documentation_url': 'https://developer.github.com/v3/issues/#create-an-issue'}
# 422 {'message': 'Validation Failed', 'errors': [{'resource': 'Issue', 'code': 'missing_field', 'field': 'title'}], 'documentation_url': 'https://developer.github.com/v3/issues/#create-an-issue'}
# 422 {'message': 'Validation Failed', 'errors': [{'resource': 'Issue', 'code': 'missing_field', 'field': 'title'}], 'documentation_url': 'https://developer.github.com/v3/issues/#create-an-issue'}
# 422 {'message': 'Validation Failed', 'errors': [{'resource': 'Issue', 'code': 'missing_field', 'field': 'title'}], 'documentation_url': 'https://developer.github.com/v3/issues/#create-an-issue'}
# 422 {'message': 'Validation Failed', 'errors': [{'resource': 'Issue', 'code': 'missing_field', 'field': 'title'}], 'documentation_url': 'https://developer.github.com/v3/issues/#create-an-issue'}
# 422 {'message': 'Validation Failed', 'errors': [{'resource': 'Issue', 'code': 'missing_field', 'field': 'title'}], 'documentation_url': 'https://developer.github.com/v3/issues/#create-an-issue'}
# 422 {'message': 'Validation Failed', 'errors': [{'resource': 'Issue', 'code': 'missing_field', 'field': 'title'}], 'documentation_url': 'https://developer.github.com/v3/issues/#create-an-issue'}
# 422 {'message': 'Validation Failed', 'errors': [{'resource': 'Issue', 'code': 'missing_field', 'field': 'title'}], 'documentation_url': 'https://developer.github.com/v3/issues/#create-an-issue'}
# 422 {'message': 'Validation Failed', 'errors': [{'resource': 'Issue', 'code': 'missing_field', 'field': 'title'}], 'documentation_url': 'https://developer.github.com/v3/issues/#create-an-issue'}
# 422 {'message': 'Validation Failed', 'errors': [{'resource': 'Issue', 'code': 'missing_field', 'field': 'title'}], 'documentation_url': 'https://developer.github.com/v3/issues/#create-an-issue'}
# 422 {'message': 'Validation Failed', 'errors': [{'resource': 'Issue', 'code': 'missing_field', 'field': 'title'}], 'documentation_url': 'https://developer.github.com/v3/issues/#create-an-issue'}
# 422 {'message': 'Validation Failed', 'errors': [{'resource': 'Issue', 'code': 'missing_field', 'field': 'title'}], 'documentation_url': 'https://developer.github.com/v3/issues/#create-an-issue'}
# 422 {'message': 'Validation Failed', 'errors': [{'resource': 'Issue', 'code': 'missing_field', 'field': 'title'}], 'documentation_url': 'https://developer.github.com/v3/issues/#create-an-issue'}
# 422 {'message': 'Validation Failed', 'errors': [{'resource': 'Issue', 'code': 'missing_field', 'field': 'title'}], 'documentation_url': 'https://developer.github.com/v3/issues/#create-an-issue'}
# 422 {'message': 'Validation Failed', 'errors': [{'resource': 'Issue', 'code': 'missing_field', 'field': 'title'}], 'documentation_url': 'https://developer.github.com/v3/issues/#create-an-issue'}
# 422 {'message': 'Validation Failed', 'errors': [{'resource': 'Issue', 'code': 'missing_field', 'field': 'title'}], 'documentation_url': 'https://developer.github.com/v3/issues/#create-an-issue'}
# 422 {'message': 'Validation Failed', 'errors': [{'resource': 'Issue', 'code': 'missing_field', 'field': 'title'}], 'documentation_url': 'https://developer.github.com/v3/issues/#create-an-issue'}
# 422 {'message': 'Validation Failed', 'errors': [{'resource': 'Issue', 'code': 'missing_field', 'field': 'title'}], 'documentation_url': 'https://developer.github.com/v3/issues/#create-an-issue'}
# 422 {'message': 'Validation Failed', 'errors': [{'resource': 'Issue', 'code': 'missing_field', 'field': 'title'}], 'documentation_url': 'https://developer.github.com/v3/issues/#create-an-issue'}
# 422 {'message': 'Validation Failed', 'errors': [{'resource': 'Issue', 'code': 'missing_field', 'field': 'title'}], 'documentation_url': 'https://developer.github.com/v3/issues/#create-an-issue'}
# 422 {'message': 'Validation Failed', 'errors': [{'resource': 'Issue', 'code': 'missing_field', 'field': 'title'}], 'documentation_url': 'https://developer.github.com/v3/issues/#create-an-issue'}
# 422 {'message': 'Validation Failed', 'errors': [{'resource': 'Label', 'field': 'name', 'code': 'missing_field'}], 'documentation_url': 'https://developer.github.com/v3/issues/#create-an-issue'}
# 422 {'message': 'Validation Failed', 'errors': [{'resource': 'Label', 'field': 'name', 'code': 'missing_field'}], 'documentation_url': 'https://developer.github.com/v3/issues/#create-an-issue'}
